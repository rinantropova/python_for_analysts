# %%
import pandas as pd

# %%
users = pd.read_csv('users.csv', sep=',')
users.head()
# Out:
#    CustomerId   Surname Geography  Gender  Age  EstimatedSalary
# 0    15634602  Hargrave    France  Female   42        101348.88
# 1    15647311      Hill     Spain  Female   41        112542.58
# 2    15619304      Onio    France  Female   42        113931.57
# 3    15701354      Boni    France  Female   39         93826.63
# 4    15737888  Mitchell     Spain  Female   43         79084.10

# %%
users.shape
# Out:
# (9998, 6)

# %% [markdown]
# ## Creating new features

# %%
users['new_feature'] = 0
users.head()
# Out:
#    CustomerId   Surname Geography  Gender  Age  EstimatedSalary  new_feature
# 0    15634602  Hargrave    France  Female   42        101348.88            0
# 1    15647311      Hill     Spain  Female   41        112542.58            0
# 2    15619304      Onio    France  Female   42        113931.57            0
# 3    15701354      Boni    France  Female   39         93826.63            0
# 4    15737888  Mitchell     Spain  Female   43         79084.10            0

# %%
users['Age (days)'] = users['Age'] * 365
users.head()
# Out:
#    CustomerId   Surname Geography  Gender  Age  EstimatedSalary  new_feature  \
# 0    15634602  Hargrave    France  Female   42        101348.88            0
# 1    15647311      Hill     Spain  Female   41        112542.58            0
# 2    15619304      Onio    France  Female   42        113931.57            0
# 3    15701354      Boni    France  Female   39         93826.63            0
# 4    15737888  Mitchell     Spain  Female   43         79084.10            0
#
#    Age (days)
# 0       15330
# 1       14965
# 2       15330
# 3       14235
# 4       15695

# %%
for i, row in users.iloc[:2].iterrows():
    print(row)
    print('__' * 30)
# Out:
# CustomerId          15634602
# Surname             Hargrave
# Geography             France
# Gender                Female
# Age                       42
# EstimatedSalary    101348.88
# new_feature                0
# Age (days)             15330
# Name: 0, dtype: object
# ____________________________________________________________
# CustomerId          15647311
# Surname                 Hill
# Geography              Spain
# Gender                Female
# Age                       41
# EstimatedSalary    112542.58
# new_feature                0
# Age (days)             14965
# Name: 1, dtype: object
# ____________________________________________________________

# %%
age_days = []

for i, row in users.iterrows():
    age_days.append(row['Age'] * 365)

age_days[:10]
# Out:
# [15330, 14965, 15330, 14235, 15695, 16060, 18250, 10585, 16060, 9855]

# %%
users['Age (days) 2'] = age_days
users.head()
# Out:
#    CustomerId   Surname Geography  Gender  Age  EstimatedSalary  new_feature  \
# 0    15634602  Hargrave    France  Female   42        101348.88            0
# 1    15647311      Hill     Spain  Female   41        112542.58            0
# 2    15619304      Onio    France  Female   42        113931.57            0
# 3    15701354      Boni    France  Female   39         93826.63            0
# 4    15737888  Mitchell     Spain  Female   43         79084.10            0
#
#    Age (days)  Age (days) 2
# 0       15330         15330
# 1       14965         14965
# 2       15330         15330
# 3       14235         14235
# 4       15695         15695

# %%
def age_to_days(x):
    return x * 365

users['Age (days) 3'] = users['Age'].apply(age_to_days)
users.head()
# Out:
#    CustomerId   Surname Geography  Gender  Age  EstimatedSalary  new_feature  \
# 0    15634602  Hargrave    France  Female   42        101348.88            0
# 1    15647311      Hill     Spain  Female   41        112542.58            0
# 2    15619304      Onio    France  Female   42        113931.57            0
# 3    15701354      Boni    France  Female   39         93826.63            0
# 4    15737888  Mitchell     Spain  Female   43         79084.10            0
#
#    Age (days)  Age (days) 2  Age (days) 3
# 0       15330         15330         15330
# 1       14965         14965         14965
# 2       15330         15330         15330
# 3       14235         14235         14235
# 4       15695         15695         15695

# %%
import time
from tqdm import tqdm
tqdm.pandas()

def age_to_days(x):
    time.sleep(0.001)
    return x * 365

users['Age'].progress_apply(age_to_days)
# Out:
# 100%|██████████| 10000/10000 [00:15<00:00, 663.38it/s]
# 0       15330
# 1       14965
# 2       15330
# 3       14235
# 4       15695
#         ...
# 9995    14235
# 9996    12775
# 9997    13140
# 9998    15330
# 9999    10220
# Name: Age, Length: 10000, dtype: int64

# %% [markdown]
# ## Removing features

# %%
users.drop(columns='new_feature')
# Out:
#       CustomerId    Surname Geography  Gender  Age  EstimatedSalary  \
# 0       15634602   Hargrave    France  Female   42        101348.88
# 1       15647311       Hill     Spain  Female   41        112542.58
# 2       15619304       Onio    France  Female   42        113931.57
# 3       15701354       Boni    France  Female   39         93826.63
# 4       15737888   Mitchell     Spain  Female   43         79084.10
# ...          ...        ...       ...     ...  ...              ...
# 9993    15606229   Obijiaku    France    Male   39         96270.64
# 9994    15569892  Johnstone    France    Male   35        101699.77
# 9995    15584532        Liu    France  Female   36         42085.58
# 9996    15682355  Sabbatini   Germany    Male   42         92888.52
# 9997    15628319     Walker    France  Female   28         38190.78
#
#       Age (days)  Age (days) 2  Age (days) 3
# 0          15330         15330         15330
# 1          14965         14965         14965
# 2          15330         15330         15330
# 3          14235         14235         14235
# 4          15695         15695         15695
# ...          ...           ...           ...
# 9993       14235         14235         14235
# 9994       12775         12775         12775
# 9995       13140         13140         13140
# 9996       15330         15330         15330
# 9997       10220         10220         10220
#
# [9998 rows x 9 columns]

# %%
users.drop(columns='new_feature')
users.head()
# Out:
#    CustomerId   Surname Geography  Gender  Age  EstimatedSalary  new_feature  \
# 0    15634602  Hargrave    France  Female   42        101348.88            0
# 1    15647311      Hill     Spain  Female   41        112542.58            0
# 2    15619304      Onio    France  Female   42        113931.57            0
# 3    15701354      Boni    France  Female   39         93826.63            0
# 4    15737888  Mitchell     Spain  Female   43         79084.10            0
#
#    Age (days)  Age (days) 2  Age (days) 3
# 0       15330         15330         15330
# 1       14965         14965         14965
# 2       15330         15330         15330
# 3       14235         14235         14235
# 4       15695         15695         15695

# %%
users = users.drop(columns='new_feature')
users.head()
# Out:
#    CustomerId   Surname Geography  Gender  Age  EstimatedSalary  Age (days)  \
# 0    15634602  Hargrave    France  Female   42        101348.88       15330
# 1    15647311      Hill     Spain  Female   41        112542.58       14965
# 2    15619304      Onio    France  Female   42        113931.57       15330
# 3    15701354      Boni    France  Female   39         93826.63       14235
# 4    15737888  Mitchell     Spain  Female   43         79084.10       15695
#
#    Age (days) 2  Age (days) 3
# 0         15330         15330
# 1         14965         14965
# 2         15330         15330
# 3         14235         14235
# 4         15695         15695

# %%
users['new_feature'] = 0

# %%
users.drop(columns='new_feature', inplace=True)
users.head()
# Out:
#    CustomerId   Surname Geography  Gender  Age  EstimatedSalary  Age (days)  \
# 0    15634602  Hargrave    France  Female   42        101348.88       15330
# 1    15647311      Hill     Spain  Female   41        112542.58       14965
# 2    15619304      Onio    France  Female   42        113931.57       15330
# 3    15701354      Boni    France  Female   39         93826.63       14235
# 4    15737888  Mitchell     Spain  Female   43         79084.10       15695
#
#    Age (days) 2  Age (days) 3
# 0         15330         15330
# 1         14965         14965
# 2         15330         15330
# 3         14235         14235
# 4         15695         15695

# %%
users.drop(columns=['Age (days)', 'Age (days) 2', 'Age (days) 3'], inplace=True)
users.head()
# Out:
#    CustomerId   Surname Geography  Gender  Age  EstimatedSalary
# 0    15634602  Hargrave    France  Female   42        101348.88
# 1    15647311      Hill     Spain  Female   41        112542.58
# 2    15619304      Onio    France  Female   42        113931.57
# 3    15701354      Boni    France  Female   39         93826.63
# 4    15737888  Mitchell     Spain  Female   43         79084.10

# %% [markdown]
# ## Modifying existing features

# %% [markdown]
# ### _.loc_

# %%
users['target'] = 0
users.head()
# Out:
#    CustomerId   Surname Geography  Gender  Age  EstimatedSalary  target
# 0    15634602  Hargrave    France  Female   42        101348.88       0
# 1    15647311      Hill     Spain  Female   41        112542.58       0
# 2    15619304      Onio    France  Female   42        113931.57       0
# 3    15701354      Boni    France  Female   39         93826.63       0
# 4    15737888  Mitchell     Spain  Female   43         79084.10       0

# %%
users.loc[users['Geography'] == 'France']
# Out:
#       CustomerId    Surname Geography  Gender  Age  EstimatedSalary  target
# 0       15634602   Hargrave    France  Female   42        101348.88       0
# 2       15619304       Onio    France  Female   42        113931.57       0
# 3       15701354       Boni    France  Female   39         93826.63       0
# 6       15592531   Bartlett    France    Male   50         10062.80       0
# 8       15792365         He    France    Male   44         74940.50       0
# ...          ...        ...       ...     ...  ...              ...     ...
# 9992    15719294       Wood    France  Female   29        167773.55       0
# 9993    15606229   Obijiaku    France    Male   39         96270.64       0
# 9994    15569892  Johnstone    France    Male   35        101699.77       0
# 9995    15584532        Liu    France  Female   36         42085.58       0
# 9997    15628319     Walker    France  Female   28         38190.78       0
#
# [5012 rows x 7 columns]

# %%
users.loc[users['Geography'] == 'France', 'target']
# Out:
# 0       0
# 2       0
# 3       0
# 6       0
# 8       0
#        ..
# 9992    0
# 9993    0
# 9994    0
# 9995    0
# 9997    0
# Name: target, Length: 5012, dtype: int64

# %%
users[users['Geography'] == 'France']['target'] = 1
users.head()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_12948\1082220520.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   users[users['Geography'] == 'France']['target'] = 1
#    CustomerId   Surname Geography  Gender  Age  EstimatedSalary  target
# 0    15634602  Hargrave    France  Female   42        101348.88       0
# 1    15647311      Hill     Spain  Female   41        112542.58       0
# 2    15619304      Onio    France  Female   42        113931.57       0
# 3    15701354      Boni    France  Female   39         93826.63       0
# 4    15737888  Mitchell     Spain  Female   43         79084.10       0

# %%
users.loc[users['Geography'] == 'France','target'] = 1
users.head()
# Out:
#    CustomerId   Surname Geography  Gender  Age  EstimatedSalary  target
# 0    15634602  Hargrave    France  Female   42        101348.88       1
# 1    15647311      Hill     Spain  Female   41        112542.58       0
# 2    15619304      Onio    France  Female   42        113931.57       1
# 3    15701354      Boni    France  Female   39         93826.63       1
# 4    15737888  Mitchell     Spain  Female   43         79084.10       0

# %% [markdown]
# ### _.replace_

# %%
users['Gender'].replace({'Female': 'F', 'Male': 'M'}, inplace=True)
users.head()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_12948\2997403862.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   users['Gender'].replace({'Female': 'F', 'Male': 'M'}, inplace=True)
#    CustomerId   Surname Geography Gender  Age  EstimatedSalary  target
# 0    15634602  Hargrave    France      F   42        101348.88       1
# 1    15647311      Hill     Spain      F   41        112542.58       0
# 2    15619304      Onio    France      F   42        113931.57       1
# 3    15701354      Boni    France      F   39         93826.63       1
# 4    15737888  Mitchell     Spain      F   43         79084.10       0

# %% [markdown]
# ## Aggregation methods

# %%
users['Age'].agg(['min', 'max'])
# Out:
# min    18
# max    92
# Name: Age, dtype: int64

# %%
users.agg({
    'Age': ['min', 'max'],
    'EstimatedSalary': 'mean'
})
# Out:
#        Age  EstimatedSalary
# min   18.0              NaN
# max   92.0              NaN
# mean   NaN    100094.144415

# %%
users.agg(
    min_age=('Age', 'min'),
    max_age=('Age', 'max'),
    mean_salary=('EstimatedSalary', 'mean')
)
# Out:
#               Age  EstimatedSalary
# min_age      18.0              NaN
# max_age      92.0              NaN
# mean_salary   NaN    100094.144415

# %% [markdown]
# ## Methods of Merging

# %%
bank = pd.read_csv('bank.csv', sep=',')
bank.head()
# Out:
#    CustomerId  CreditScore  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0    15592531          822       7       0.00              2          1
# 1    15656148          376       4  115046.74              4          1
# 2    15792365          501       4  142051.07              2          0
# 3    15592389          684       2  134603.88              1          1
# 4    15767821          528       6  102016.72              2          0
#
#    IsActiveMember  Exited
# 0               1       0
# 1               0       1
# 2               1       0
# 3               1       0
# 4               0       0

# %%
bank.shape
# Out:
# (9994, 8)

# %%
merged = users.merge(bank, left_on='CustomerId', right_on='CustomerId')
merged.head()
# Out:
#    CustomerId   Surname Geography Gender  Age  EstimatedSalary  target  \
# 0    15592531  Bartlett    France      M   50         10062.80       1
# 1    15656148    Obinna   Germany      F   29        119346.88       0
# 2    15792365        He    France      M   44         74940.50       1
# 3    15592389        H?    France      M   27         71725.73       1
# 4    15767821    Bearce    France      M   31         80181.12       1
#
#    CreditScore  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          822       7       0.00              2          1               1
# 1          376       4  115046.74              4          1               0
# 2          501       4  142051.07              2          0               1
# 3          684       2  134603.88              1          1               1
# 4          528       6  102016.72              2          0               0
#
#    Exited
# 0       0
# 1       1
# 2       0
# 3       0
# 4       0

# %%
users_id = users.set_index('CustomerId')
users_id.head()
# Out:
#              Surname Geography Gender  Age  EstimatedSalary  target
# CustomerId
# 15634602    Hargrave    France      F   42        101348.88       1
# 15647311        Hill     Spain      F   41        112542.58       0
# 15619304        Onio    France      F   42        113931.57       1
# 15701354        Boni    France      F   39         93826.63       1
# 15737888    Mitchell     Spain      F   43         79084.10       0

# %%
bank_id = bank.set_index('CustomerId')
bank_id.head()
# Out:
#             CreditScore  Tenure    Balance  NumOfProducts  HasCrCard  \
# CustomerId
# 15592531            822       7       0.00              2          1
# 15656148            376       4  115046.74              4          1
# 15792365            501       4  142051.07              2          0
# 15592389            684       2  134603.88              1          1
# 15767821            528       6  102016.72              2          0
#
#             IsActiveMember  Exited
# CustomerId
# 15592531                 1       0
# 15656148                 0       1
# 15792365                 1       0
# 15592389                 1       0
# 15767821                 0       0

# %%
bank_id.join(users_id).head()
# Out:
#             CreditScore  Tenure    Balance  NumOfProducts  HasCrCard  \
# CustomerId
# 15592531            822       7       0.00              2          1
# 15656148            376       4  115046.74              4          1
# 15792365            501       4  142051.07              2          0
# 15592389            684       2  134603.88              1          1
# 15767821            528       6  102016.72              2          0
#
#             IsActiveMember  Exited   Surname Geography Gender   Age  \
# CustomerId
# 15592531                 1       0  Bartlett    France      M  50.0
# 15656148                 0       1    Obinna   Germany      F  29.0
# 15792365                 1       0        He    France      M  44.0
# 15592389                 1       0        H?    France      M  27.0
# 15767821                 0       0    Bearce    France      M  31.0
#
#             EstimatedSalary  target
# CustomerId
# 15592531           10062.80     1.0
# 15656148          119346.88     0.0
# 15792365           74940.50     1.0
# 15592389           71725.73     1.0
# 15767821           80181.12     1.0

# %%
bank_id.join(users_id).reset_index().head()
# Out:
#    CustomerId  CreditScore  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0    15592531          822       7       0.00              2          1
# 1    15656148          376       4  115046.74              4          1
# 2    15792365          501       4  142051.07              2          0
# 3    15592389          684       2  134603.88              1          1
# 4    15767821          528       6  102016.72              2          0
#
#    IsActiveMember  Exited   Surname Geography Gender   Age  EstimatedSalary  \
# 0               1       0  Bartlett    France      M  50.0         10062.80
# 1               0       1    Obinna   Germany      F  29.0        119346.88
# 2               1       0        He    France      M  44.0         74940.50
# 3               1       0        H?    France      M  27.0         71725.73
# 4               0       0    Bearce    France      M  31.0         80181.12
#
#    target
# 0     1.0
# 1     0.0
# 2     1.0
# 3     1.0
# 4     1.0

# %%
bank.shape
# Out:
# (9994, 8)

# %% [markdown]
# ##### **Atribute how**
# ![image.png](attachment:1394ec44-7bbe-4aab-a0fa-517820661340.png)

# %% [markdown]
# ###### _**left**_

# %%
merged_left = bank.merge(users, on='CustomerId', how='left')
merged_left.shape
# Out:
# (9994, 14)

# %%
merged_left.isna().sum()
# Out:
# CustomerId         0
# CreditScore        0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# Exited             0
# Surname            2
# Geography          2
# Gender             2
# Age                2
# EstimatedSalary    2
# target             2
# dtype: int64

# %%
merged_left[merged_left['Age'].isna()]
# Out:
#     CustomerId  CreditScore  Tenure   Balance  NumOfProducts  HasCrCard  \
# 77    15701164          506       4  90307.62              1          1
# 78    15738751          493       4      0.00              2          1
#
#     IsActiveMember  Exited Surname Geography Gender  Age  EstimatedSalary  \
# 77               1       0     NaN       NaN    NaN  NaN              NaN
# 78               0       0     NaN       NaN    NaN  NaN              NaN
#
#     target
# 77     NaN
# 78     NaN

# %%
users[users['CustomerId'] == 15701164]
# Out:
# Empty DataFrame
# Columns: [CustomerId, Surname, Geography, Gender, Age, EstimatedSalary, target]
# Index: []

# %% [markdown]
# ###### _**right**_

# %%
merged_right = bank.merge(users, on='CustomerId', how='right')
merged_right.shape
# Out:
# (9998, 14)

# %%
merged_right.isna().sum()
# Out:
# CustomerId         0
# CreditScore        6
# Tenure             6
# Balance            6
# NumOfProducts      6
# HasCrCard          6
# IsActiveMember     6
# Exited             6
# Surname            0
# Geography          0
# Gender             0
# Age                0
# EstimatedSalary    0
# target             0
# dtype: int64

# %%
merged_right[merged_right['CreditScore'].isna()]
# Out:
#    CustomerId  CreditScore  Tenure  Balance  NumOfProducts  HasCrCard  \
# 0    15634602          NaN     NaN      NaN            NaN        NaN
# 1    15647311          NaN     NaN      NaN            NaN        NaN
# 2    15619304          NaN     NaN      NaN            NaN        NaN
# 3    15701354          NaN     NaN      NaN            NaN        NaN
# 4    15737888          NaN     NaN      NaN            NaN        NaN
# 5    15574012          NaN     NaN      NaN            NaN        NaN
#
#    IsActiveMember  Exited   Surname Geography Gender  Age  EstimatedSalary  \
# 0             NaN     NaN  Hargrave    France      F   42        101348.88
# 1             NaN     NaN      Hill     Spain      F   41        112542.58
# 2             NaN     NaN      Onio    France      F   42        113931.57
# 3             NaN     NaN      Boni    France      F   39         93826.63
# 4             NaN     NaN  Mitchell     Spain      F   43         79084.10
# 5             NaN     NaN       Chu     Spain      M   44        149756.71
#
#    target
# 0       1
# 1       0
# 2       1
# 3       1
# 4       0
# 5       0

# %%
bank[bank['CustomerId'] == 15634602]
# Out:
# Empty DataFrame
# Columns: [CustomerId, CreditScore, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, Exited]
# Index: []

# %% [markdown]
# ###### _**inner**_

# %%
merged_inner = bank.merge(users, on='CustomerId', how='inner')
merged_inner.shape
# Out:
# (9992, 14)

# %%
merged_inner.isna().sum()
# Out:
# CustomerId         0
# CreditScore        0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# Exited             0
# Surname            0
# Geography          0
# Gender             0
# Age                0
# EstimatedSalary    0
# target             0
# dtype: int64

# %% [markdown]
# ###### _**outer**_

# %%
merged_outer = bank.merge(users, on='CustomerId', how='outer')
merged_outer.shape
# Out:
# (10000, 14)

# %%
merged_outer.isna().sum()
# Out:
# CustomerId         0
# CreditScore        6
# Tenure             6
# Balance            6
# NumOfProducts      6
# HasCrCard          6
# IsActiveMember     6
# Exited             6
# Surname            2
# Geography          2
# Gender             2
# Age                2
# EstimatedSalary    2
# target             2
# dtype: int64

# %% [markdown]
# ## Grouping methods

# %% [markdown]
# #### groupby
# ![image.png](attachment:c23edd11-3a17-460b-a87b-391acaf13442.png)

# %%
toy_df = pd.DataFrame({
    'client_id': [1, 2, 2, 3, 1, 1],
    'item': ['chocolate', 'cheese', 'ham', 'candy', 'chair', 'book'],
    'price': [68, 280, 302, 39, 2099, 1089]
})
toy_df
# Out:
#    client_id       item  price
# 0          1  chocolate     68
# 1          2     cheese    280
# 2          2        ham    302
# 3          3      candy     39
# 4          1      chair   2099
# 5          1       book   1089

# %%
grouped = toy_df.groupby('client_id')
grouped

# %%
grouped.groups
# Out:
# {1: [0, 4, 5], 2: [1, 2], 3: [3]}

# %%
grouped.sum()
# Out:
#                          item  price
# client_id
# 1          chocolatechairbook   3256
# 2                   cheeseham    582
# 3                       candy     39

# %%
grouped.agg({'price': ['sum', 'min', 'max']})
# Out:
#           price
#             sum  min   max
# client_id
# 1          3256   68  2099
# 2           582  280   302
# 3            39   39    39

# %%
users.groupby('Geography').agg({'Age': ['mean'], 'EstimatedSalary': ['min']})
# Out:
#                  Age EstimatedSalary
#                 mean             min
# Geography
# France     38.511173           90.07
# Germany    39.771622           11.58
# Spain      38.890997          417.41

# %% [markdown]
# #### pivot_table

# %%
toy_df
# Out:
#    client_id       item  price
# 0          1  chocolate     68
# 1          2     cheese    280
# 2          2        ham    302
# 3          3      candy     39
# 4          1      chair   2099
# 5          1       book   1089

# %%
toy_df.pivot_table(index='client_id',
                  values='price',
                  aggfunc='sum')
# Out:
#            price
# client_id
# 1           3256
# 2            582
# 3             39

# %%
users.pivot_table(index='Geography',
                 aggfunc={'Age': ['mean'], 'EstimatedSalary': 'min'})
# Out:
#                  Age EstimatedSalary
#                 mean             min
# Geography
# France     38.511173           90.07
# Germany    39.771622           11.58
# Spain      38.890997          417.41

# %%
users.pivot_table(index='Geography',
                 columns='Gender',
                 values='EstimatedSalary',
                 aggfunc='mean',
                 margins=True,
                 margins_name='Total')
# Out:
# Gender                 F              M          Total
# Geography
# France      99581.067964  100174.252495   99906.893386
# Germany    102446.424124   99905.033959  101113.435102
# Spain      100734.107475   98425.687680   99440.572281
# Total      100610.363257   99664.576931  100094.144415

# %% [markdown]
# #### crosstab

# %%
pd.crosstab(index=users['Geography'],
           columns=users['Gender'])
# Out:
# Gender        F     M
# Geography
# France     2259  2753
# Germany    1193  1316
# Spain      1089  1388

# %%
pd.crosstab(index=users['Geography'],
           columns=users['Gender'],
           values=users['EstimatedSalary'],
           aggfunc='mean')
# Out:
# Gender                 F              M
# Geography
# France      99581.067964  100174.252495
# Germany    102446.424124   99905.033959
# Spain      100734.107475   98425.687680

# %%
pd.crosstab(index=users['Geography'],
           columns=users['Gender'],
           normalize='all')
# Out:
# Gender            F         M
# Geography
# France     0.225945  0.275355
# Germany    0.119324  0.131626
# Spain      0.108922  0.138828

# %%
pd.crosstab(index=users['Geography'],
           columns=users['Gender'],
           normalize='index')
# Out:
# Gender            F         M
# Geography
# France     0.450718  0.549282
# Germany    0.475488  0.524512
# Spain      0.439645  0.560355

# %%
pd.crosstab(index=users['Geography'],
           columns=users['Gender'],
           normalize='columns')
# Out:
# Gender            F         M
# Geography
# France     0.497468  0.504490
# Germany    0.262717  0.241158
# Spain      0.239815  0.254352

# %% [markdown]
# ## Embedded visualizations

# %%
users['Age'].hist();

# %%
data = users.groupby('Gender').count()['Age']
data.name = 'Gender'
data
# Out:
# Gender
# F    4541
# M    5457
# Name: Gender, dtype: int64

# %%
data.plot.pie(y='Gender');

# %%
users.iloc[:100].plot.scatter(x='Age', y='EstimatedSalary');

# %%
data = bank.groupby('Tenure').count()['Balance']
data.name = 'num_clients'
data
# Out:
# Tenure
# 0      413
# 1     1033
# 2     1046
# 3     1009
# 4      989
# 5     1012
# 6      967
# 7     1028
# 8     1023
# 9      984
# 10     490
# Name: num_clients, dtype: int64

# %%
data.plot.bar(width=0.8);
