# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ## Series
# Представляет из себя объект, похожий на одномерный массив, но отличительной чертой является наличие индексов

# %%
a = pd.Series([4, 7, 6, 3, 9],
             index=['one', 'two', 'three', 'four', 'five'])
a
# Out:
# one      4
# two      7
# three    6
# four     3
# five     9
# dtype: int64

# %%
a = pd.Series([4, 7, 6, 3, 9])
a
# Out:
# 0    4
# 1    7
# 2    6
# 3    3
# 4    9
# dtype: int64

# %%
a.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
a.values
# Out:
# array([4, 7, 6, 3, 9], dtype=int64)

# %%
a[0]
# Out:
# 4

# %%
a[1]
# Out:
# 7

# %% [markdown]
# ## DataFrame
# Объект DataFrame - табличная структура данных. В любой таблице присутствуют столбцы и строки. При этом в столбцах можно хранить данные разных типов. Столбцами в объекте DataFrame выступают объекты Series, строки к-рых являются их элементами.

# %%
df = pd.DataFrame({
    'Age': [46, 37, 44, 42, 42],
    'Country': ['Spain', 'Spain', 'Germany', 'Germany', 'France'],
    'Gender': ['Female', 'Female', 'Male', 'Male', 'Male']
})
df
# Out:
#    Age  Country  Gender
# 0   46    Spain  Female
# 1   37    Spain  Female
# 2   44  Germany    Male
# 3   42  Germany    Male
# 4   42   France    Male

# %%
df['Age']
# Out:
# 0    46
# 1    37
# 2    44
# 3    42
# 4    42
# Name: Age, dtype: int64

# %%
df.Country
# Out:
# 0      Spain
# 1      Spain
# 2    Germany
# 3    Germany
# 4     France
# Name: Country, dtype: object

# %%
df[['Country', 'Age']]
# Out:
#    Country  Age
# 0    Spain   46
# 1    Spain   37
# 2  Germany   44
# 3  Germany   42
# 4   France   42

# %%
df.columns
# Out:
# Index(['Age', 'Country', 'Gender'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df = pd.DataFrame({
    'Age': [46, 37, 44, 42, 42],
    'Country': ['Spain', 'Spain', 'Germany', 'Germany', 'France'],
    'Gender': ['Female', 'Female', 'Male', 'Male', 'Male']
}, index=[5, 4, 6, 3, 12])
df
# Out:
#     Age  Country  Gender
# 5    46    Spain  Female
# 4    37    Spain  Female
# 6    44  Germany    Male
# 3    42  Germany    Male
# 12   42   France    Male

# %%
df.index = [101, 102, 103, 104, 105]
df
# Out:
#      Age  Country  Gender
# 101   46    Spain  Female
# 102   37    Spain  Female
# 103   44  Germany    Male
# 104   42  Germany    Male
# 105   42   France    Male

# %% [markdown]
# ## Data reading
# the most often used file type is .csv(comma separated values)
#
# The dataset is the details of the customers in a company.

# %%
df = pd.read_csv('./Churn_Modelling.csv')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
pd.read_csv('./Churn_Modelling.csv', header=1)
# Out:
#           1  15634602   Hargrave  619   France  Female  42   2          0  \
# 0         2  15647311       Hill  608    Spain  Female  41   1   83807.86
# 1         3  15619304       Onio  502   France  Female  42   8  159660.80
# 2         4  15701354       Boni  699   France  Female  39   1       0.00
# 3         5  15737888   Mitchell  850    Spain  Female  43   2  125510.82
# 4         6  15574012        Chu  645    Spain    Male  44   8  113755.78
# ...     ...       ...        ...  ...      ...     ...  ..  ..        ...
# 9994   9996  15606229   Obijiaku  771   France    Male  39   5       0.00
# 9995   9997  15569892  Johnstone  516   France    Male  35  10   57369.61
# 9996   9998  15584532        Liu  709   France  Female  36   7       0.00
# 9997   9999  15682355  Sabbatini  772  Germany    Male  42   3   75075.31
# 9998  10000  15628319     Walker  792   France  Female  28   4  130142.79
#
#       1.1  1.2  1.3  101348.88  1.4
# 0       1    0    1  112542.58    0
# ...

# %%
pd.read_csv('./Churn_Modelling.csv', sep=',')
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
df.sample()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 5501       5502    15796496  Trevisani          631    France  Female   31
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 5501       8  137687.72              1          1               0
#
#       EstimatedSalary  Exited
# 5501        190067.12       0

# %%
df.sample(frac=1)
# Out:
#       RowNumber  CustomerId       Surname  CreditScore Geography  Gender  Age  \
# 7550       7551    15801817     Carpenter          688    France  Female   38
# 9811       9812    15772421     Tretiakov          645   Germany  Female   31
# 8962       8963    15607874         Keane          687    France    Male   38
# 8229       8230    15603550         Longo          588   Germany  Female   37
# 9640       9641    15647203       Gebhart          750    France  Female   35
# ...         ...         ...           ...          ...       ...     ...  ...
# 497         498    15733616  Sopuluchukwu          806    France    Male   40
# 2581       2582    15634719     Chinwendu          704    France    Male   31
# 6126       6127    15790935       Johnson          535    France  Female   29
# 7394       7395    15673747         Ayers          519    France  Female   22
# 9688       9689    15730579          Ward          850    France    Male   68
#
# ...

# %%
df.sample(frac=0.5)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 6879       6880    15772618      Tyler          665    France    Male   25
# 3431       3432    15688193     Graham          468    France    Male   36
# 6802       6803    15700656  Balashova          662    France    Male   32
# 4192       4193    15610147       Ross          632    France    Male   60
# 2138       2139    15688619      Scott          718     Spain    Male   45
# ...         ...         ...        ...          ...       ...     ...  ...
# 3731       3732    15568573     Graham          554   Germany  Female   51
# 7113       7114    15783859       Boni          733    France  Female   24
# 1744       1745    15682533     Hughes          850    France  Female   39
# 5399       5400    15628904      Bowen          733     Spain    Male   35
# 3296       3297    15755018  Dickinson          568   Germany  Female   26
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %% [markdown]
# ## Primary Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# Выводятся следующие данные:
#
# * Count - amount of filled in objects (where there is no nan values)
# * mean - arithmethic mean
# * std - standard deviation
# * min - minimal value
# * 25% - quantile 25%
# * 50% - quantile 50%
# * 75% - quantile 75%
# * max - maximal value

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df['Age'].min()
# Out:
# 18

# %%
df['Balance'].max()
# Out:
# 250898.09

# %%
df[['CreditScore', 'Age', 'Tenure']].mean()
# Out:
# CreditScore    650.5288
# Age             38.9218
# Tenure           5.0128
# dtype: float64

# %%
df.describe(include=['object'])
# method describe by default doesn't return boolean or string data types
# Out:
#        Surname Geography Gender
# count    10000     10000  10000
# unique    2932         3      2
# top      Smith    France   Male
# freq        32      5014   5457

# %% [markdown]
# * unique - amount of unique values
# * top - самое частотное значение (мода)
# * freq - частота появления самого частотного значения

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df['Age'].dtype
# Out:
# dtype('int64')

# %%
df['HasCrCard'].astype('bool')
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 9995     True
# 9996     True
# 9997    False
# 9998     True
# 9999     True
# Name: HasCrCard, Length: 10000, dtype: bool

# %%
df['HasCrCard'].dtype
# Out:
# dtype('int64')

# %%
df['HasCrCard'] = df['HasCrCard'].astype('bool')

# %%
df['HasCrCard'].dtype
# Out:
# dtype('bool')

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df['Geography'].nunique()
# Out:
# 3

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
df['Geography'].value_counts(normalize=True)
# Out:
# Geography
# France     0.5014
# Germany    0.2509
# Spain      0.2477
# Name: proportion, dtype: float64

# %% [markdown]
# ## Filtration
# Filtration in pandas is performed based on boolean masks
#
# Булевая маска - это бинарные данные, которые используются для выбора определенных объектов из структуры данных

# %%
df['Gender'] == 'Male'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995     True
# 9996     True
# 9997    False
# 9998     True
# 9999    False
# Name: Gender, Length: 10000, dtype: bool

# %%
male = df[df['Gender'] == 'Male']
male
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography Gender  Age  \
# 5             6    15574012          Chu          645     Spain   Male   44
# 6             7    15592531     Bartlett          822    France   Male   50
# 8             9    15792365           He          501    France   Male   44
# 9            10    15592389           H?          684    France   Male   27
# 10           11    15767821       Bearce          528    France   Male   31
# ...         ...         ...          ...          ...       ...    ...  ...
# 9992       9993    15657105  Chukwualuka          726     Spain   Male   36
# 9993       9994    15569266       Rahman          644    France   Male   28
# 9995       9996    15606229     Obijiaku          771    France   Male   39
# 9996       9997    15569892    Johnstone          516    France   Male   35
# 9998       9999    15682355    Sabbatini          772   Germany   Male   42
#
# ...

# %% [markdown]
# ## Логическое И
# both conditions should be applied

# %%
df[(df['Gender'] == 'Female') & (df['NumOfProducts'] >= 3)]
# Out:
#       RowNumber  CustomerId        Surname  CreditScore Geography  Gender  \
# 2             3    15619304           Onio          502    France  Female
# 7             8    15656148         Obinna          376   Germany  Female
# 30           31    15589475        Azikiwe          591     Spain  Female
# 88           89    15622897         Sharpe          646    France  Female
# 90           91    15757535           Heap          647     Spain  Female
# ...         ...         ...            ...          ...       ...     ...
# 9565       9566    15752294           Long          582    France  Female
# 9747       9748    15775761  Iweobiegbunam          610   Germany  Female
# 9800       9801    15640507             Li          762     Spain  Female
# 9877       9878    15572182     Onwuamaeze          505   Germany  Female
# 9895       9896    15796764          Bruno          684   Germany  Female
#
#       Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ## Логическое ИЛИ
# at least one condition should be applied

# %%
df[(df['HasCrCard']) | (df['NumOfProducts'] >= 3)]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 2             3    15619304       Onio          502    France  Female   42
# 4             5    15737888   Mitchell          850     Spain  Female   43
# 5             6    15574012        Chu          645     Spain    Male   44
# 6             7    15592531   Bartlett          822    France    Male   50
# ...         ...         ...        ...          ...       ...     ...  ...
# 9993       9994    15569266     Rahman          644    France    Male   28
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ## Логическое НЕ
#
# булевая маска обращается - True меняется на False  и наоборот.

# %%
df[~(df['Geography'] == 'Spain')]
# we're removing Spain from the dataset with this operation
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 6             7    15592531   Bartlett          822    France    Male   50
# 7             8    15656148     Obinna          376   Germany  Female   29
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df[df['Geography'].isin(['France', 'Germany'])]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 6             7    15592531   Bartlett          822    France    Male   50
# 7             8    15656148     Obinna          376   Germany  Female   29
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ## Indexation

# %%
df_small = df[(df['Geography'] == 'Spain')][['Geography', 'Gender', 'Age']]
df_small.head()
# Out:
#    Geography  Gender  Age
# 1      Spain  Female   41
# 4      Spain  Female   43
# 5      Spain    Male   44
# 11     Spain    Male   24
# 14     Spain  Female   35

# %% [markdown]
# ## loc

# %%
df_small.loc[1]
# Out:
# Geography     Spain
# Gender       Female
# Age              41
# Name: 1, dtype: object

# %%
df_small.loc[5]
# Out:
# Geography    Spain
# Gender        Male
# Age             44
# Name: 5, dtype: object

# %%
df_small.loc[[1, 4, 5], ['Gender', 'Age']]
# Out:
#    Gender  Age
# 1  Female   41
# 4  Female   43
# 5    Male   44

# %% [markdown]
# ## iloc

# %%
df_small.head()
# Out:
#    Geography  Gender  Age
# 1      Spain  Female   41
# 4      Spain  Female   43
# 5      Spain    Male   44
# 11     Spain    Male   24
# 14     Spain  Female   35

# %%
df_small.iloc[[0, 1, 2]]
# Out:
#   Geography  Gender  Age
# 1     Spain  Female   41
# 4     Spain  Female   43
# 5     Spain    Male   44

# %%
df_small.iloc[2500]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 df_small.iloc[2500]
#
# File ~\anaconda3\envs\PythonForAnalysts\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\envs\PythonForAnalysts\Lib\site-packages\pandas\core\indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# ...

# %%
df_small.iloc[0, [0, 2]]
# Out:
# Geography    Spain
# Age             41
# Name: 1, dtype: object

# %% [markdown]
# ## Sorting

# %%
df.sort_values('Age')
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 3512       3513    15657779       Boylan          806     Spain    Male   18
# 1678       1679    15569178    Kharlamov          570    France  Female   18
# 3517       3518    15757821      Burgess          771     Spain    Male   18
# 9520       9521    15673180  Onyekaozulu          727   Germany  Female   18
# 2021       2022    15795519     Vasiliev          716   Germany  Female   18
# ...         ...         ...          ...          ...       ...     ...  ...
# 3387       3388    15798024         Lori          537   Germany    Male   84
# 3033       3034    15578006          Yao          787    France  Female   85
# 2458       2459    15813303      Rearick          513     Spain    Male   88
# 6759       6760    15660878        T'ien          705    France    Male   92
# 6443       6444    15764927       Rogova          753    France    Male   92
#
# ...

# %%
df.sort_values('Age', ascending=False)
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 6443       6444    15764927       Rogova          753    France    Male   92
# 6759       6760    15660878        T'ien          705    France    Male   92
# 2458       2459    15813303      Rearick          513     Spain    Male   88
# 3033       3034    15578006          Yao          787    France  Female   85
# 3387       3388    15798024         Lori          537   Germany    Male   84
# ...         ...         ...          ...          ...       ...     ...  ...
# 9782       9783    15728829       Weigel          509    France    Male   18
# 2141       2142    15758372      Wallace          674    France    Male   18
# 9501       9502    15634146          Hou          835   Germany    Male   18
# 9520       9521    15673180  Onyekaozulu          727   Germany  Female   18
# 1619       1620    15770309     McDonald          656    France    Male   18
#
# ...

# %%
df.sort_values(['Age', 'CreditScore'])
# Out:
#       RowNumber  CustomerId          Surname  CreditScore Geography  Gender  \
# 9782       9783    15728829           Weigel          509    France    Male
# 1678       1679    15569178        Kharlamov          570    France  Female
# 9029       9030    15722701            Bruno          594   Germany    Male
# 7334       7335    15759133          Vaguine          616    France    Male
# 9526       9527    15665521  Chiazagomekpele          642   Germany    Male
# ...         ...         ...              ...          ...       ...     ...
# 3387       3388    15798024             Lori          537   Germany    Male
# 3033       3034    15578006              Yao          787    France  Female
# 2458       2459    15813303          Rearick          513     Spain    Male
# 6759       6760    15660878            T'ien          705    France    Male
# 6443       6444    15764927           Rogova          753    France    Male
#
# ...
